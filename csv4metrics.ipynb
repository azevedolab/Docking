# %% [markdown]
# # **csv4metrics: CSV for Metrics**
# This program evaluates the predictive performance of a scoring function and generates a scattering plot between the predicted and experimental binding affinity. It employs DOME (Data, Optimization, Model, and Evaluation in Machine Learning) ([Walsh et al., 2021](https://doi.org/10.1038/s41592-021-01205-4)) and EDOME (Extended DOME) ([de Azevedo et al., 2024](https://doi.org/10.1002/jcc.27449)) metrics to estimate the predictive performance of regression models built using Molegro Data Modeller (MDM) ([Thomsen & Christensen, 2006](https://doi.org/10.1021/jm051197e); [Bitencourt-Ferreira & de Azevedo, 2019](https://doi.org/10.1007/978-1-4939-9752-7_10)).
# <br> </br>
# <img src="https://drive.usercontent.google.com/download?id=1cESa_w6n2OO5t3OTAFQu-P3Sla2k9aIV&export=view&authuser=0" width=600 alt="csv4metrics">
# <br><i>Schematic flowchart for csv4metrics. It reads binding affinity data from a CSV file generated with Molegro Virtual Docker (MVD) ([Thomsen & Christensen, 2006](https://doi.org/10.1021/jm051197e); [Bitencourt-Ferreira & de Azevedo, 2019](https://doi.org/10.1007/978-1-4939-9752-7_10)) and creates a scatter plot for predicted and experimental values. It determines the predictive performance of scoring functions using metrics defined elsewhere ([Walsh et 2021](https://doi.org/10.1038/s41592-021-01205-4); [de Azevedo et al., 2024](https://doi.org/10.1002/jcc.27449)).</i></br>
# <br></br>
# **References**
# <br></br>
# Bitencourt-Ferreira G, de Azevedo WF Jr. Molegro Virtual Docker for Docking. Methods Mol Biol. 2019;2053:149-167. PMID: 31452104. [DOI: 10.1007/978-1-4939-9752-7_10](https://doi.org/10.1007/978-1-4939-9752-7_10) [PubMed](https://pubmed.ncbi.nlm.nih.gov/31452104/)
# <br></br>
# De Azevedo WF Jr, Quiroga R, Villarreal MA, da Silveira NJF, Bitencourt-Ferreira G, da Silva AD, Veit-Acosta M, Oliveira PR, Tutone M, Biziukova N, Poroikov V, Tarasova O, Baud S. SAnDReS 2.0: Development of machine-learning models to explore the scoring function space. J Comput Chem. 2024; 45(27): 2333-2346. PMID: 38900052. [DOI: 10.1002/jcc.27449](https://doi.org/10.1002/jcc.27449) [PubMed](https://pubmed.ncbi.nlm.nih.gov/38900052/)
# <br></br>
# Thomsen R, Christensen MH. MolDock: a new technique for high-accuracy molecular docking. J Med Chem. 2006; 49(11): 3315-21. [DOI: 10.1021/jm051197e](https://doi.org/10.1021/jm051197e) [PubMed](https://pubmed.ncbi.nlm.nih.gov/16722650/)
# <br></br>
# Walsh I, Fishman D, Garcia-Gasulla D, Titma T, Pollastri G; ELIXIR Machine
# Learning Focus Group; Harrow J, Psomopoulos FE, Tosatto SCE. DOME:
# recommendations for supervised machine learning validation in biology.
# Nat Methods. 2021; 18(10): 1122-1127.
# [DOI: 10.1038/s41592-021-01205-4]
# (https://doi.org/10.1038/s41592-021-01205-4)
# [PubMed](https://pubmed.ncbi.nlm.nih.gov/34316068/)
# <br></br>
#
# It follows the complete Python code.

# %%
#!/usr/bin/env python3
#
################################################################################
# Dr. Walter F. de Azevedo, Jr.                                                #
# [Scopus](https://www.scopus.com/authid/detail.uri?authorId=7006435557)       #
# [GitHub](https://github.com/azevedolab)                                      #
# January 12, 2025                                                             #
################################################################################

# %% [markdown]
# **Walsh_and_de_Azevedo_regression_metrics(y,y_pred)**
# <br> </br>
#
#     Function to calculate regression metrics as recommended by
#     [Walsh et 2021](https://pubmed.ncbi.nlm.nih.gov/34316068/)
#     and
#     [de Azevedo Jr et al., 2024](https://pubmed.ncbi.nlm.nih.gov/38900052/)).
#
#     Parameters:
#     y (dataframe):                  y
#     y_test (dataframe):             y test set
#
#     where n is the number of instances.
#
#     <br></br>
#     **References**
#     <br> </br>
#     De Azevedo WF Jr, Quiroga R, Villarreal MA, da Silveira NJF,
#     Bitencourt-Ferreira G, da Silva AD, Veit-Acosta M, Oliveira PR, Tutone M,
#     Biziukova N, Poroikov V, Tarasova O, Baud S. SAnDReS 2.0: Development of
#     machine-learning models to explore the scoring function space. J Comput
#     Chem. 2024; 45(27): 2333-2346.
#     PMID: 38900052. [DOI: 10.1002/jcc.27449](https://doi.org/10.1002/jcc.27449)
#     [PubMed](https://pubmed.ncbi.nlm.nih.gov/38900052/)
#     <br></br>
#     Walsh I, Fishman D, Garcia-Gasulla D, Titma T, Pollastri G; ELIXIR Machine
#     Learning Focus Group; Harrow J, Psomopoulos FE, Tosatto SCE. DOME:
#     recommendations for supervised machine learning validation in biology.
#     Nat Methods. 2021; 18(10): 1122-1127.
#     [DOI: 10.1038/s41592-021-01205-4]
#     (https://doi.org/10.1038/s41592-021-01205-4)
#     [PubMed](https://pubmed.ncbi.nlm.nih.gov/34316068/)
#     <br></br>

# %%
def Walsh_and_de_Azevedo_regression_metrics(y,y_pred):
    """Function to calculate regression metrics as recommended by
    [Walsh et 2021](https://pubmed.ncbi.nlm.nih.gov/34316068/)
    and
    [de Azevedo Jr et al., 2024](https://pubmed.ncbi.nlm.nih.gov/38900052/)).

    <br></br>
    **References**
    <br> </br>
    De Azevedo WF Jr, Quiroga R, Villarreal MA, da Silveira NJF,
    Bitencourt-Ferreira G, da Silva AD, Veit-Acosta M, Oliveira PR, Tutone M,
    Biziukova N, Poroikov V, Tarasova O, Baud S. SAnDReS 2.0: Development of
    machine-learning models to explore the scoring function space. J Comput
    Chem. 2024; 45(27): 2333-2346.
    PMID: 38900052. [DOI: 10.1002/jcc.27449](https://doi.org/10.1002/jcc.27449)
    [PubMed](https://pubmed.ncbi.nlm.nih.gov/38900052/)
    <br></br>
    Walsh I, Fishman D, Garcia-Gasulla D, Titma T, Pollastri G; ELIXIR Machine
    Learning Focus Group; Harrow J, Psomopoulos FE, Tosatto SCE. DOME:
    recommendations for supervised machine learning validation in biology.
    Nat Methods. 2021; 18(10): 1122-1127.
    [DOI: 10.1038/s41592-021-01205-4](https://doi.org/10.1038/s41592-021-01205-4)
    [PubMed](https://pubmed.ncbi.nlm.nih.gov/34316068/)
    <br></br>
    """
    # Import section
    from sklearn.metrics import median_absolute_error
    from scipy import stats
    import numpy as np

    # Determine metrics
    n = len(y)
    y_bar = y.mean()
    rss = np.sum( np.square(y_pred - y) )
    rmse =  np.sqrt( (np.sum( (y - y_pred)**2 ))/n )
    ss_res = np.sum( (y - y_pred)**2 )
    ss_tot = np.sum( (y - y_bar)**2 )
    R2 = 1 - ss_res/ss_tot
    mae = median_absolute_error(y,y_pred)
    r_pearson,p_pearson = stats.pearsonr(y,y_pred)
    rho,p_spearman = stats.spearmanr(y,y_pred)
    core_dome = rmse**2 + mae**2 + (R2 -1)**2
    dome =    np.sqrt( core_dome )
    edomer2 = np.sqrt( core_dome + (r_pearson**2 - 1)**2 )
    edomerho =np.sqrt( core_dome + (rho**2 - 1)**2 )
    edome =   np.sqrt( core_dome + (r_pearson**2 - 1)**2 + (rho**2 - 1)**2 )

    # Return metrics
    return r_pearson,p_pearson,rho,p_spearman,rss,rmse,mae,R2,dome,edomer2,\
    edomerho,edome

# %% [markdown]
# **scatter_plot(y,y_pred,
#                 n_points,point_type,
#                 color4data,color4models,
#                 xlabel,ylabel,title,
#                 xlabel_fontsize,ylabel_fontsize,title_fontsize,
#                 xlim,ylim,
#                 grid_on,
#                 plt_out,plt_dpi)**
#     <br> </br>
#
#     Function to generate a basic scatter plot with data points and a
#     regression model line. It employs the Matplotlib library
#     (https://matplotlib.org/) to build a requested plot. It follows the
#     code implemented in the program SAnDReS 2.0
#     ([de Azevedo et al., 2024](https://doi.org/10.1002/jcc.27449)).
#
#     Parameters:
#
#     y (dataframe):                  y
#     y_test (dataframe):             y test set
#     n_points (integer):             Number of points to create an array
#     point_type (string):            Type of data points (e.g., ".")
#     color4data (string):            Color for data points
#     color4models (string):          Color for regression models
#     scatter_xlabel (string):        X-axis label
#     scatter_ylabel (string):        y-axis label
#     title (string):                 Plot title
#     xlabel_fontsize (integer):      X-label font size
#     ylabel_fontsize (integer):      y-label font size
#     title_fontsize (integer):       Title font size
#     xlim (tuple):                   X-axis limits
#     ylim (tuple):                   y-axis limits
#     grid_on (boolean):              Turn grid on
#     plt_out (string):               Plot file name
#     plt_dpi (integer):              dpi for output plot
#
#     <br></br>
#     **Reference**
#     <br></br>
#     De Azevedo WF Jr, Quiroga R, Villarreal MA, da Silveira NJF,
#     Bitencourt-Ferreira G, da Silva AD, Veit-Acosta M, Oliveira PR, Tutone M,
#     Biziukova N, Poroikov V, Tarasova O, Baud S. SAnDReS 2.0: Development of
#     machine-learning models to explore the scoring function space. J Comput
#     Chem. 2024; 45(27): 2333-2346.
#     PMID: 38900052. [DOI: 10.1002/jcc.27449](https://doi.org/10.1002/jcc.27449)
#     [PubMed](https://pubmed.ncbi.nlm.nih.gov/38900052/)
#     <br></br>

# %%
def scatter_plot(exp,pred,
                n_points,point_type,
                color4data,color4models,
                xlabel,ylabel,title,
                xlabel_fontsize,ylabel_fontsize,title_fontsize,
                xlim,ylim,
                grid_on,
                plt_out,plt_dpi):
    """Function to generate a basic scatter plot with data points and a
    regression model line. It relies on [matplotlib](https://matplotlib.org/)
    library to build a requested plot.
    """
    # Import section
    import numpy as np
    import matplotlib.pyplot as plt

    # Obtain m (slope) and b(intercept) of a regression line
    m, b = np.polyfit(exp,pred, 1)

    # Set up an array
    y_in = np.linspace(xlim[0], xlim[1], num = n_points)

    # Create basic scatterplot
    plt.plot(exp, pred,point_type,color = color4data)

    # Use color4models as color for regression model
    plt.plot(y_in, m*y_in+b, color=color4models)
    plt.xlabel(xlabel,fontsize = xlabel_fontsize)
    plt.ylabel(ylabel,fontsize = ylabel_fontsize)
    plt.title(title,fontsize = title_fontsize)
    plt.xlim(xlim)
    plt.ylim(ylim)
    plt.grid(grid_on)
    plt.savefig(plt_out,dpi = plt_dpi)
    plt.show()
    plt.close()

# %% [markdown]
# Define main() function

# %%
def main():
    # Import section
    import pandas as pd

    # Define Google Drive variables
    drvstr1 = "https://drive.usercontent.google.com/u/0/uc?id="
    drvstr2 = "&export=download"

    # Define inputs for each dataset
    ############################################################################
    # Cyclin-dependent kinase/G2/mitotic-specific cyclin- 1 [ 181 ]
    ############################################################################
    # CSV file: CDK1_Rerank_Binding_Affinity_Test_Set_ANN_21_10_3_1.csv
    # Google drive ID (for CSV file): 1QzHSIomb8U4-cwGFtuIP4utLMYpkY1mt
    # Molegro Data Modeller Model (MDM): CDK1_ANN.mdm
    # Google drive ID (for MDM file): 1AngVKBFuYlkVfvnqDAV2gkTBbzl9ypDr
    ############################################################################
    id="1QzHSIomb8U4-cwGFtuIP4utLMYpkY1mt" # Google drive ID
    dataset_tag = "_test_set"              # String for dataset tag
    exp_target = "pKi"                     # Target variable
    pred_target = "ANN (21-10-3-1)"        # Variable for predicted values
    #pred_target = "RerankScore"           # Variable for predicted values

    ############################################################################
    # Cyclin-dependent kinase/G2/mitotic-specific cyclin- 1 [ 181 ]
    ############################################################################
    # CSV file: CDK1_Rerank_Binding_Affinity_Training_Set_ANN_21_10_3_1.csv
    # Google drive ID (for CSV file): 1YejtAw2Uphlcsz_NdgcaQhgdwVpAUMp_
    # Molegro Data Modeller Model (MDM): CDK1_ANN.mdm
    # Google drive ID (for MDM file): 1AngVKBFuYlkVfvnqDAV2gkTBbzl9ypDr
    ############################################################################
    #id="1YejtAw2Uphlcsz_NdgcaQhgdwVpAUMp_" # Google drive ID
    #dataset_tag = "_training_set"          # String for dataset tag
    #exp_target = "pKi"                     # Target variable
    #pred_target = "ANN (21-10-3-1)"        # Variable for predicted values
    #pred_target = "RerankScore"            # Variable for predicted values

    ############################################################################
    ############################################################################

    ############################################################################
    # Cyclin-dependent kinase 2/G1/S-specific cyclin-E1 [ 1450 (2102) ]
    ############################################################################
    # CSV file: CDK2_Rerank_Binding_Affinity_Test_Set_ANN_27_6_3_1.csv
    # Google drive ID (for CSV file): 1ZFuYhgzPQKGHwEBM6frE5RkLS1thPyHu
    # Molegro Data Modeller Model (MDM): CDK2_ANN.mdm
    # Google drive ID (for MDM file): 1Ms9DXMf_550-k1Ighk-GqY0YFpjg5plN
    ############################################################################
    #id="1ZFuYhgzPQKGHwEBM6frE5RkLS1thPyHu" # Google drive ID
    #dataset_tag = "_test_set"              # String for dataset tag
    #exp_target = "pKi"                     # Target variable
    #pred_target = "ANN (27-6-3-1)"         # Variable for predicted values
    #pred_target = "RerankScore"           # Variable for predicted values

    ############################################################################
    # Cyclin-dependent kinase 2/G1/S-specific cyclin-E1 [ 1450 (2102) ]
    ############################################################################
    # CSV file: CDK2_Rerank_Binding_Affinity_Training_Set_ANN_27_6_3_1.csv
    # Google drive ID (for CSV file): 1nVynWW0ZBfHrk4rv8R7BrAwPrrj1N4P0
    # Molegro Data Modeller Model (MDM): CDK2_ANN.mdm
    # Google drive ID (for MDM file): 1Ms9DXMf_550-k1Ighk-GqY0YFpjg5plN
    ############################################################################
    #id="1nVynWW0ZBfHrk4rv8R7BrAwPrrj1N4P0" # Google drive ID
    #dataset_tag = "_training_set"          # String for dataset tag
    #exp_target = "pKi"                     # Target variable
    #pred_target = "ANN (27-6-3-1)"         # Variable for predicted values
    #pred_target = "RerankScore"            # Variable for predicted values

    ############################################################################
    ############################################################################

    ############################################################################
    # Cyclin-A2/Cyclin-dependent kinase 2 [ 164 ]
    ############################################################################
    # CSV file: CDK2-CyclinA2_Ki_Plants_Binding_Affinity_Test_Set_MLR.csv
    # Google drive ID (for CSV file): 1qy7AfpKXGRsok0j3ObRO2NSm4ZkX_3aQ
    # Molegro Data Modeller Model (MDM): MLR_CDK2-CyclinA2_Ki_Plants.mdm
    # Google drive ID (for MDM file): 144-6cHjHuShKK0F6lkJ9sQByvA0P30FC
    ############################################################################
    #id="1qy7AfpKXGRsok0j3ObRO2NSm4ZkX_3aQ" # Google drive ID
    #dataset_tag = "_test_set"              # String for dataset tag
    #exp_target = "pKi"                     # Target variable
    #pred_target = "MLR (28D)"              # Variable for predicted values
    #pred_target = "PlantsScore"            # Variable for predicted values

    ############################################################################
    # Cyclin-A2/Cyclin-dependent kinase 2 [ 164 ]
    ############################################################################
    # CSV file: CDK2-CyclinA2_Ki_Plants_Binding_Affinity_Training_Set_MLR.csv
    # Google drive ID (for CSV file): 1EenDgQNaOJazj3RanP0g6c_xG5q-Sjyj
    # Molegro Data Modeller Model (MDM): MLR_CDK2-CyclinA2_Ki_Plants.mdm
    # Google drive ID (for MDM file): 144-6cHjHuShKK0F6lkJ9sQByvA0P30FC
    ############################################################################
    #id="1EenDgQNaOJazj3RanP0g6c_xG5q-Sjyj" # Google drive ID
    #dataset_tag = "_training_set"          # String for dataset tag
    #exp_target = "pKi"                     # Target variable
    #pred_target = "MLR (28D)"              # Variable for predicted values
    #pred_target = "PlantsScore"            # Variable for predicted values

    ############################################################################
    ############################################################################

    ############################################################################
    # Cyclin-A2/Cyclin-dependent kinase 2 [ 164 ]
    ############################################################################
    # CSV file: CDK2-CyclinA2_Ki_Plants_Binding_Affinity_Test_Set_SVR.csv
    # Google drive ID (for CSV file): 1Rc58gV1yUNqqBs6aKCpPmsgYhIKD9tvp
    # Molegro Data Modeller Model (MDM): SVM(35SV)_CDK2-CyclinA2_Ki_Plants.mdm
    # Google drive ID (for MDM file): 1V99a3_n_6epAUbMra01KDak4KbVR6m1M
    ############################################################################
    #id="1Rc58gV1yUNqqBs6aKCpPmsgYhIKD9tvp" # Google drive ID
    #dataset_tag = "_test_set"              # String for dataset tag
    #exp_target = "pKi"                     # Target variable
    #pred_target = "SVM (35SV)"             # Variable for predicted values
    #pred_target = "PlantsScore"            # Variable for predicted values

    ############################################################################
    # Cyclin-A2/Cyclin-dependent kinase 2 [ 164 ]
    ############################################################################
    # CSV file: CDK2-CyclinA2_Ki_Plants_Binding_Affinity_Training_Set_SVR.csv
    # Google drive ID (for CSV file): 1DKipLFYtBx4C6E3M7liCoj8SF6zmBbGG
    # Molegro Data Modeller Model (MDM): SVM(35SV)_CDK2-CyclinA2_Ki_Plants.mdm
    # Google drive ID (for MDM file): 1V99a3_n_6epAUbMra01KDak4KbVR6m1M
    ############################################################################
    #id="1DKipLFYtBx4C6E3M7liCoj8SF6zmBbGG" # Google drive ID
    #dataset_tag = "_training_set"          # String for dataset tag
    #exp_target = "pKi"                     # Target variable
    #pred_target = "SVM (35SV)"             # Variable for predicted values
    #pred_target = "PlantsScore"            # Variable for predicted values

    ############################################################################
    ############################################################################

    ############################################################################
    # Cyclin-A2/Cyclin-dependent kinase 2 [ 164 ]
    ############################################################################
    # CSV file: CDK2-CyclinA2_Ki_Plants_Binding_Affinity_Test_Set_ANN_16_11_11_1.csv
    # Google drive ID (for CSV file): 1MUMHfZakN3rLLurwX_qkBc839sdCmy1J
    # Molegro Data Modeller Model (MDM): ANN_16_11_11_1_CDK2-CyclinA2_Ki_Plants.mdm
    # Google drive ID (for MDM file): 1IysHrkCVVcNZi5AUFBOfvvUmgF0oW1K0
    ############################################################################
    #id="1MUMHfZakN3rLLurwX_qkBc839sdCmy1J" # Google drive ID
    #dataset_tag = "_training_set"          # String for dataset tag
    #exp_target = "pKi"                     # Target variable
    #pred_target = "ANN (16-11-11-1)"       # Variable for predicted values
    #pred_target = "PlantsScore"            # Variable for predicted values

    ############################################################################
    ############################################################################

    ############################################################################
    # Cyclin-dependent kinase 4/G1/S-specific cyclin-D1 [ 455 (460) ]
    ############################################################################
    # CSV file: CDK4_Test_Set_ANN_17_11_11_1.csv
    # Google drive ID (for CSV file): 1yn-Mi4f4-6j5WIR4I3RR1QdB-XcYHIwH
    # Molegro Data Modeller Model (MDM): CDK4_ANN.mdm
    # Google drive ID (for MDM file): 1EpRVQVCtNmi0jjILrBp__6OAcZHBChae
    ############################################################################
    #id="1yn-Mi4f4-6j5WIR4I3RR1QdB-XcYHIwH" # Google drive ID
    #dataset_tag = "_test_set"              # String for dataset tag
    #exp_target = "pKi"                     # Target variable
    #pred_target = "ANN (17-11-11-1)"       # Variable for predicted values
    #pred_target = "PlantsScore"            # Variable for predicted values

    ############################################################################
    # Cyclin-dependent kinase 4/G1/S-specific cyclin-D1 [ 455 (460) ]
    ############################################################################
    # CSV file: CDK4_Training_Set_ANN_17_11_11_1.csv
    # Google drive ID (for CSV file): 1qnxMOMgFifnuCwEr1uGle_vE9WcEuuWo
    # Molegro Data Modeller Model (MDM): CDK4_ANN_17_11_11_1.mdm
    # Google drive ID (for MDM file): 1EpRVQVCtNmi0jjILrBp__6OAcZHBChae
    ############################################################################
    #id="1qnxMOMgFifnuCwEr1uGle_vE9WcEuuWo" # Google drive ID
    #dataset_tag = "_train_set"             # String for dataset tag
    #exp_target = "pKi"                     # Target variable
    #pred_target = "ANN (17-11-11-1)"       # Variable for predicted values
    #pred_target = "PlantsScore"            # Variable for predicted values

    ############################################################################
    ############################################################################

    ############################################################################
    # Cyclin-dependent kinase 6/G1/S-specific cyclin-D1 [ 415 ]
    ############################################################################
    # CSV file: CDK6_Plants_Binding_Affinity_Test_Set_ANN_26_8_6_1.csv
    # Google drive ID (for CSV file): 1n99oItRksSZz6rKi6vu_qgFPwZ5EHda2
    # Molegro Data Modeller Model (MDM): CDK6_ANN.mdm
    # Google drive ID (for MDM file): 196E73Pve_qaZaTU9lEynti7UexKvU3r5
    ############################################################################
    #id="1oe7Oi5xxpE0Qi_AsgPKp_LOfa292NU6c" # Google drive ID
    #dataset_tag = "_test_set"              # String for dataset tag
    #exp_target = "pKi"                     # Target variable
    #pred_target = "ANN (26-8-6-1)"         # Variable for predicted values
    #pred_target = "PlantsScore"            # Variable for predicted values

    ############################################################################
    # Cyclin-dependent kinase 6/G1/S-specific cyclin-D1 [ 415 ]
    ############################################################################
    # CSV file: CDK6_Plants_Binding_Affinity_Training_Set_ANN_26_8_6_1.csv
    # Google drive ID (for CSV file):
    # Molegro Data Modeller Model (MDM): CDK6_ANN.mdm
    # Google drive ID (for MDM file): 196E73Pve_qaZaTU9lEynti7UexKvU3r5
    ############################################################################
    #id="1s4TCKGfDqAjoMDkHmyE8L2AE5CMGbCRx" # Google drive ID
    #dataset_tag = "_train_set"             # String for dataset tag
    #exp_target = "pKi"                     # Target variable
    #pred_target = "ANN (26-8-6-1)"         # Variable for predicted values
    #pred_target = "PlantsScore"            # Variable for predicted values

    ############################################################################
    ############################################################################

    ############################################################################
    # Cyclin-H/Cyclin-dependent kinase 7 [ 123 ]
    ############################################################################
    # CSV file: CDK7_Rerank_Binding_Affinity_Test_Set_ANN_29_4_9_1.csv
    # Google drive ID (for CSV file): 1fD9JIaqdyTwt86lyrMRKX_te-VyF03q8
    # Molegro Data Modeller Model (MDM): CDK7_ANN.mdm
    # Google drive ID (for MDM file): 1X5fCWBVguVF5s3xJ6B_N1eNBRtP-i_sk
    ############################################################################
    #id="1fD9JIaqdyTwt86lyrMRKX_te-VyF03q8" # Google drive ID
    #dataset_tag = "_test_set"              # String for dataset tag
    #exp_target = "pKi"                     # Target variable
    #pred_target = "ANN (29-4-9-1)"         # Variable for predicted values
    #pred_target = "RerankScore"            # Variable for predicted values

    ############################################################################
    # Cyclin-H/Cyclin-dependent kinase 7 [ 123 ]
    ############################################################################
    # CSV file: CDK7_Rerank_Binding_Affinity_Training_Set_ANN_29_4_9_1.csv
    # Google drive ID (for CSV file): 1qukVV7IW6UR9_z3nGojTLTGuH9PLR7b7
    # Molegro Data Modeller Model (MDM): CDK7_ANN.mdm
    # Google drive ID (for MDM file): 1X5fCWBVguVF5s3xJ6B_N1eNBRtP-i_sk
    ############################################################################
    #id="1qukVV7IW6UR9_z3nGojTLTGuH9PLR7b7" # Google drive ID
    #dataset_tag = "_train_set"             # String for dataset tag
    #exp_target = "pKi"                     # Target variable
    #pred_target = "ANN (29-4-9-1)"         # Variable for predicted values
    #pred_target = "RerankScore"            # Variable for predicted values

    ############################################################################
    ############################################################################

    ############################################################################
    # Cyclin-T1/Cyclin-dependent kinase 9 [ 201 ]
    ############################################################################
    # CSV file: CDK9_Test_Set_ANN_27_5_9_1.csv
    # Google drive ID (for CSV file): 1Zj6rJ-OPqAXwKEQljsaGy4XrmlSzTRrX
    # Molegro Data Modeller Model (MDM): CDK9_ANN.mdm
    # Google drive ID (for MDM file): 1waCkcmEx_U2euYMTvRYLPDdnIUxeUU2Q
    ############################################################################
    #id="1Zj6rJ-OPqAXwKEQljsaGy4XrmlSzTRrX" # Google drive ID
    #dataset_tag = "_test_set"              # String for dataset tag
    #exp_target = "pKi"                     # Target variable
    #pred_target = "ANN (27-5-9-1)"         # Variable for predicted values
    #pred_target = "PlantsScore"            # Variable for predicted values

    ############################################################################
    # Cyclin-T1/Cyclin-dependent kinase 9 [ 201 ]
    ############################################################################
    # CSV file: CDK9_Training_Set_ANN_27_5_9_1.csv
    # Google drive ID (for CSV file): 1GneSsbn4vYjF-E24-4qYtEHPpbs-n0ft
    # Molegro Data Modeller Model (MDM): CDK9_ANN.mdm
    # Google drive ID (for MDM file): 1waCkcmEx_U2euYMTvRYLPDdnIUxeUU2Q
    ############################################################################
    #id="1GneSsbn4vYjF-E24-4qYtEHPpbs-n0ft" # Google drive ID
    #dataset_tag = "_training_set"          # String for dataset tag
    #exp_target = "pKi"                     # Target variable
    #pred_target = "ANN (27-5-9-1)"         # Variable for predicted values
    #pred_target = "PlantsScore"            # Variable for predicted values

    ############################################################################
    ############################################################################

    ############################################################################
    # Cyclin-C/Cyclin-dependent kinase 19 [ 123 (124) ]
    ############################################################################
    # CSV file: CDK19_Rerank_Binding_Affinity_Test_Set_ANN_30-4-3-1.csv
    # Google drive ID (for CSV file): 1bJFxsqrNXQ3sdTe-hZVpBkRS6zQgazUU
    # Molegro Data Modeller Model (MDM): CDK19_ANN_30-4-3-1.mdm
    # Google drive ID (for MDM file): 121rg3c42_w64Is0rV3Wwxtq8C-XWfnIJ
    ############################################################################
    #id="1bJFxsqrNXQ3sdTe-hZVpBkRS6zQgazUU" # Google drive ID
    #dataset_tag = "_test_set"              # String for dataset tag
    #exp_target = "pIC50"                   # Target variable
    #pred_target = "ANN (30-4-3-1)"         # Variable for predicted values
    #pred_target = "RerankScore"            # Variable for predicted values

    ############################################################################
    # Cyclin-C/Cyclin-dependent kinase 19 [ 123 (124) ]
    ############################################################################
    # CSV file: CDK19_Rerank_Binding_Affinity_Training_Set_ANN_30-4-3-1.csv
    # Google drive ID (for CSV file): 10qV9FuvgWBJRrKV2Pt_PPzXm1cOBm0A1
    # Molegro Data Modeller Model (MDM): CDK19_ANN_30-4-3-1.mdm
    # Google drive ID (for MDM file): 121rg3c42_w64Is0rV3Wwxtq8C-XWfnIJ
    ############################################################################
    #id="10qV9FuvgWBJRrKV2Pt_PPzXm1cOBm0A1" # Google drive ID
    #dataset_tag = "_traning_set"           # String for dataset tag
    #exp_target = "pIC50"                   # Target variable
    #pred_target = "ANN (30-4-3-1)"         # Variable for predicted values
    #pred_target = "RerankScore"            # Variable for predicted values

    ############################################################################
    ############################################################################

    # Read CSV
    url = drvstr1+id+drvstr2               # Google drive url
    print("\nReading Google Drive ID: "+id,end="...")
    data_in = pd.read_csv(url,delimiter=",")
    exp_data = data_in[exp_target]         # Experimental data
    pred_data= data_in[pred_target]        # Predicted values
    print("done!")

    # For scatter plot
    xlim = (4.0, 10.0)                     # Tuple with x-axis limits
    ylim = (4.0, 10.0)                     # Tuple with y-axis limits
    #xlim = (5.0, 11.0)                    # Tuple with x-axis limits
    #ylim = (5.0, 11.0)                    # Tuple with y-axis limits
    #xlim = (5.0, 12.0)                    # Tuple with x-axis limits
    #ylim = (5.0, 12.0)                    # Tuple with y-axis limits
    #ylim = (-100.0, -50.0)                # Tuple with y-axis limits
    #ylim = (-100.0, -20.0)                # Tuple with y-axis limits
    #ylim = (-100.0, -40.0)                # Tuple with y-axis limits
    #ylim = (-140.0, -20.0)                # Tuple with y-axis limits
    scatter_xlabel="pK$_{i}$ (Experimental)" # Label for x-axis
    scatter_ylabel = "pK$_{i}$ (Predicted)"  # Label for y-axis
    #scatter_xlabel="pIC$_{50}$ (Experimental)" # Label for x-axis
    #scatter_ylabel = "pIC$_{50}$ (Predicted)"  # Label for y-axis
    #scatter_ylabel = "Plants Score (au)"  # Label for y-axis
    #scatter_ylabel = "Rerank Score (au)"  # Label for y-axis
    n_points = 100                         # Number of points to create an array
    point_type = "."                       # Type of data points (e.g., ".")
    color4data = "blue"                    # Color for data points
    color4models = "black"                 # Color for regression models
    xlabel_fontsize = 14                   # X-label font size
    ylabel_fontsize = 14                   # y-label font size
    title_fontsize = 12                    # Title font size
    grid_on = True                         # Turn grid on
    plt_dpi = 1500                         # dpi for output plot
    t_root = "CDK1 K$_{i}$ (Test Set)"     # Plot title root
    #t_root = "CDK1 K$_{i}$ (Training Set)"# Plot title root
    #t_root = "CDK2 K$_{i}$ (Test Set)"    # Plot title root
    #t_root = "CDK2 K$_{i}$ (Training Set)"# Plot title root
    #t_root = "CDK4 K$_{i}$ (Test Set)"    # Plot title root
    #t_root = "CDK4 K$_{i}$ (Training Set)"# Plot title root
    #t_root = "CDK6 K$_{i}$ (Test Set)"    # Plot title root
    #t_root = "CDK6 K$_{i}$ (Training Set)"# Plot title root
    #t_root = "CDK7 K$_{i}$ (Test Set)"    # Plot title root
    #t_root = "CDK7 K$_{i}$ (Training Set)"# Plot title root
    #t_root = "CDK9 K$_{i}$ (Test Set)"    # Plot title root
    #t_root = "CDK9 K$_{i}$ (Training Set)"# Plot title root
    #t_root = "CDK19 IC$_{50}$ (Test Set)" # Plot title root
    #t_root = "CDK19 IC$_{50}$ (Training Set)" # Plot title root

    # Call Walsh_and_de_Azevedo_regression_metrics() function
    r_pearson,p_pearson,rho,p_spearman,rss,rmse,mae,R2,dome,edomer2,edomerho,\
    edome = Walsh_and_de_Azevedo_regression_metrics(exp_data,pred_data)

    # Define header
    data_out = "Score,n,r,p-value(r),r2,rho,p-value(rho),"
    data_out += "RSS,RMSE,MAE,R2,DOME,EDOMEr2,EDOMErho,EDOME\n"

    # Set up output line
    line_out = pred_target.replace(" ","")+","
    line_out += str(len(exp_data))+","
    line_out += "{:.4f}".format(r_pearson)+","
    line_out += "{:.4e}".format(p_pearson)+","
    line_out += "{:.4f}".format(r_pearson**2)+","
    line_out += "{:.4f}".format(rho)+","
    line_out += "{:.4e}".format(p_spearman)+","
    line_out += "{:.4e}".format(rss)+","
    line_out += "{:.4f}".format(rmse)+","
    line_out += "{:.4f}".format(mae)+","
    line_out += "{:.4f}".format(R2)+","
    line_out += "{:.4f}".format(dome)+","
    line_out += "{:.4f}".format(edomer2)+","
    line_out += "{:.4f}".format(edomerho)+","
    line_out += "{:.4f}".format(edome)
    data_out += line_out

    # Open a new file and write data_out and close it
    reg_out = pred_target.replace(" ","")+"_metrics_EDOME.csv"
    reg_out = reg_out.replace(".csv",dataset_tag+".csv")
    fo_out = open(reg_out,"w")
    fo_out.write(data_out)
    fo_out.close()
    print("\nMetrics saved to file: "+reg_out)

    # Call scatter_plot() function
    plt_out = pred_target.replace(" ","")+"_scatter_plot.pdf"
    plt_out = plt_out.replace(".pdf",dataset_tag+".pdf")
    print("\nSaving scatter plot to file: "+plt_out,end="...")
    scatter_title = t_root
    scatter_plot(exp_data,pred_data,
    n_points,point_type,
    color4data,color4models,
    scatter_xlabel,scatter_ylabel,scatter_title,
    xlabel_fontsize,ylabel_fontsize,title_fontsize,
    xlim,ylim,
    grid_on,
    plt_out,plt_dpi)
    print("done!")

# Call main() function
main()
# Out:
# Reading Google Drive ID: 1QzHSIomb8U4-cwGFtuIP4utLMYpkY1mt...done!
#
# Metrics saved to file: ANN(21-10-3-1)_metrics_EDOME_test_set.csv
#
# Saving scatter plot to file: ANN(21-10-3-1)_scatter_plot_test_set.pdf...
# done!
